# %%
import warnings

warnings.filterwarnings('ignore')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
car=pd.read_csv("E:\decodr\programs\Prediction Price of car\CarPrice.csv")

# %%
car.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %%
#finding numeric variable
car_numeric=car.select_dtypes(include=['float64','int64'])
car_numeric.head()
# Out:
#    car_ID  symboling  wheelbase  carlength  carwidth  carheight  curbweight  \
# 0       1          3       88.6      168.8      64.1       48.8        2548
# 1       2          3       88.6      168.8      64.1       48.8        2548
# 2       3          1       94.5      171.2      65.5       52.4        2823
# 3       4          2       99.8      176.6      66.2       54.3        2337
# 4       5          2       99.4      176.6      66.4       54.3        2824
#
#    enginesize  boreratio  stroke  compressionratio  horsepower  peakrpm  \
# 0         130       3.47    2.68               9.0         111     5000
# 1         130       3.47    2.68               9.0         111     5000
# 2         152       2.68    3.47               9.0         154     5000
# 3         109       3.19    3.40              10.0         102     5500
# 4         136       3.19    3.40               8.0         115     5500
#
#    citympg  highwaympg    price
# 0       21          27  13495.0
# ...

# %%
sns.pairplot(car_numeric)
plt.show()

# %%
cor=car_numeric.corr()

# %%
plt.figure(figsize=(20,20))
sns.heatmap(cor,annot=True)
plt.show()

# %%
car.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %%
car['CarName'][:30]
# Out:
# 0            alfa-romero giulia
# 1           alfa-romero stelvio
# 2      alfa-romero Quadrifoglio
# 3                   audi 100 ls
# 4                    audi 100ls
# 5                      audi fox
# 6                    audi 100ls
# 7                     audi 5000
# 8                     audi 4000
# 9           audi 5000s (diesel)
# 10                     bmw 320i
# 11                     bmw 320i
# 12                       bmw x1
# 13                       bmw x3
# 14                       bmw z4
# 15                       bmw x4
# 16                       bmw x5
# 17                       bmw x3
# 18             chevrolet impala
# 19        chevrolet monte carlo
# 20          chevrolet vega 2300
# 21                dodge rampage
# 22          dodge challenger se
# 23                   dodge d200
# 24            dodge monaco (sw)
# 25           dodge colt hardtop
# 26              dodge colt (sw)
# 27         dodge coronet custom
# 28            dodge dart custom
# ...

# %%
car['car_company']=car['CarName'].apply(lambda x: x.split(' ')[0])

# %%
car['car_company'][:50]
# Out:
# 0     alfa-romero
# 1     alfa-romero
# 2     alfa-romero
# 3            audi
# 4            audi
# 5            audi
# 6            audi
# 7            audi
# 8            audi
# 9            audi
# 10            bmw
# 11            bmw
# 12            bmw
# 13            bmw
# 14            bmw
# 15            bmw
# 16            bmw
# 17            bmw
# 18      chevrolet
# 19      chevrolet
# 20      chevrolet
# 21          dodge
# 22          dodge
# 23          dodge
# 24          dodge
# 25          dodge
# 26          dodge
# 27          dodge
# 28          dodge
# 29          dodge
# 30          honda
# 31          honda
# 32          honda
# 33          honda
# 34          honda
# 35          honda
# 36          honda
# 37          honda
# 38          honda
# 39          honda
# 40          honda
# 41          honda
# 42          honda
# 43          isuzu
# 44          isuzu
# 45          isuzu
# 46          isuzu
# 47         jaguar
# 48         jaguar
# 49         jaguar
# ...

# %%
car['car_company'][50:100]
# Out:
# 50         maxda
# 51         maxda
# 52         mazda
# 53         mazda
# 54         mazda
# 55         mazda
# 56         mazda
# 57         mazda
# 58         mazda
# 59         mazda
# 60         mazda
# 61         mazda
# 62         mazda
# 63         mazda
# 64         mazda
# 65         mazda
# 66         mazda
# 67         buick
# 68         buick
# 69         buick
# 70         buick
# 71         buick
# 72         buick
# 73         buick
# 74         buick
# 75       mercury
# 76    mitsubishi
# 77    mitsubishi
# 78    mitsubishi
# 79    mitsubishi
# 80    mitsubishi
# 81    mitsubishi
# 82    mitsubishi
# 83    mitsubishi
# 84    mitsubishi
# 85    mitsubishi
# 86    mitsubishi
# 87    mitsubishi
# 88    mitsubishi
# 89        Nissan
# 90        nissan
# 91        nissan
# 92        nissan
# 93        nissan
# 94        nissan
# 95        nissan
# 96        nissan
# 97        nissan
# 98        nissan
# 99        nissan
# Name: car_company, dtype: object

# %%
car['car_company'][100:150]
# Out:
# 100      nissan
# 101      nissan
# 102      nissan
# 103      nissan
# 104      nissan
# 105      nissan
# 106      nissan
# 107     peugeot
# 108     peugeot
# 109     peugeot
# 110     peugeot
# 111     peugeot
# 112     peugeot
# 113     peugeot
# 114     peugeot
# 115     peugeot
# 116     peugeot
# 117     peugeot
# 118    plymouth
# 119    plymouth
# 120    plymouth
# 121    plymouth
# 122    plymouth
# 123    plymouth
# 124    plymouth
# 125     porsche
# 126    porcshce
# 127     porsche
# 128     porsche
# 129     porsche
# 130     renault
# 131     renault
# 132        saab
# 133        saab
# 134        saab
# 135        saab
# 136        saab
# 137        saab
# 138      subaru
# 139      subaru
# 140      subaru
# 141      subaru
# 142      subaru
# 143      subaru
# 144      subaru
# 145      subaru
# 146      subaru
# 147      subaru
# 148      subaru
# 149      subaru
# Name: car_company, dtype: object

# %%
car['car_company'][150:]
# Out:
# 150        toyota
# 151        toyota
# 152        toyota
# 153        toyota
# 154        toyota
# 155        toyota
# 156        toyota
# 157        toyota
# 158        toyota
# 159        toyota
# 160        toyota
# 161        toyota
# 162        toyota
# 163        toyota
# 164        toyota
# 165        toyota
# 166        toyota
# 167        toyota
# 168        toyota
# 169        toyota
# 170        toyota
# 171        toyota
# 172        toyota
# 173        toyota
# 174        toyota
# 175        toyota
# 176        toyota
# 177        toyota
# 178        toyota
# 179        toyota
# 180        toyota
# 181       toyouta
# 182     vokswagen
# 183    volkswagen
# 184    volkswagen
# 185    volkswagen
# 186    volkswagen
# 187    volkswagen
# 188    volkswagen
# 189            vw
# 190            vw
# 191    volkswagen
# 192    volkswagen
# 193    volkswagen
# 194         volvo
# 195         volvo
# 196         volvo
# 197         volvo
# 198         volvo
# 199         volvo
# ...

# %%
car.loc[(car['car_company']=='vw') | (car['car_company']=='vokswagen'), 'car_company']='volkswagen'

# %% [markdown]
# # list of car companies after 150, vokswagen will be displayed as volkswagen

# %%
car['car_company'][150:]
# Out:
# 150        toyota
# 151        toyota
# 152        toyota
# 153        toyota
# 154        toyota
# 155        toyota
# 156        toyota
# 157        toyota
# 158        toyota
# 159        toyota
# 160        toyota
# 161        toyota
# 162        toyota
# 163        toyota
# 164        toyota
# 165        toyota
# 166        toyota
# 167        toyota
# 168        toyota
# 169        toyota
# 170        toyota
# 171        toyota
# 172        toyota
# 173        toyota
# 174        toyota
# 175        toyota
# 176        toyota
# 177        toyota
# 178        toyota
# 179        toyota
# 180        toyota
# 181       toyouta
# 182    volkswagen
# 183    volkswagen
# 184    volkswagen
# 185    volkswagen
# 186    volkswagen
# 187    volkswagen
# 188    volkswagen
# 189    volkswagen
# 190    volkswagen
# 191    volkswagen
# 192    volkswagen
# 193    volkswagen
# 194         volvo
# 195         volvo
# 196         volvo
# 197         volvo
# 198         volvo
# 199         volvo
# ...

# %%
car.loc[(car['car_company']=='toyouta'),'car_company']='toyota'

# %% [markdown]
# # list of car companies after 150, toyouta will be displayed as toyota

# %%
car['car_company'][150:]
# Out:
# 150        toyota
# 151        toyota
# 152        toyota
# 153        toyota
# 154        toyota
# 155        toyota
# 156        toyota
# 157        toyota
# 158        toyota
# 159        toyota
# 160        toyota
# 161        toyota
# 162        toyota
# 163        toyota
# 164        toyota
# 165        toyota
# 166        toyota
# 167        toyota
# 168        toyota
# 169        toyota
# 170        toyota
# 171        toyota
# 172        toyota
# 173        toyota
# 174        toyota
# 175        toyota
# 176        toyota
# 177        toyota
# 178        toyota
# 179        toyota
# 180        toyota
# 181        toyota
# 182    volkswagen
# 183    volkswagen
# 184    volkswagen
# 185    volkswagen
# 186    volkswagen
# 187    volkswagen
# 188    volkswagen
# 189    volkswagen
# 190    volkswagen
# 191    volkswagen
# 192    volkswagen
# 193    volkswagen
# 194         volvo
# 195         volvo
# 196         volvo
# 197         volvo
# 198         volvo
# 199         volvo
# ...

# %%
car.loc[(car['car_company']=='maxda') , 'car_company']='mazda'

# %% [markdown]
# # list of car companies between 50 and 100, maxda will be displayed as mazda

# %%
car['car_company'][50:100]
# Out:
# 50         mazda
# 51         mazda
# 52         mazda
# 53         mazda
# 54         mazda
# 55         mazda
# 56         mazda
# 57         mazda
# 58         mazda
# 59         mazda
# 60         mazda
# 61         mazda
# 62         mazda
# 63         mazda
# 64         mazda
# 65         mazda
# 66         mazda
# 67         buick
# 68         buick
# 69         buick
# 70         buick
# 71         buick
# 72         buick
# 73         buick
# 74         buick
# 75       mercury
# 76    mitsubishi
# 77    mitsubishi
# 78    mitsubishi
# 79    mitsubishi
# 80    mitsubishi
# 81    mitsubishi
# 82    mitsubishi
# 83    mitsubishi
# 84    mitsubishi
# 85    mitsubishi
# 86    mitsubishi
# 87    mitsubishi
# 88    mitsubishi
# 89        Nissan
# 90        nissan
# 91        nissan
# 92        nissan
# 93        nissan
# 94        nissan
# 95        nissan
# 96        nissan
# 97        nissan
# 98        nissan
# 99        nissan
# Name: car_company, dtype: object

# %%
car.loc[(car['car_company']=='porcshce') , 'car_company']='porsche'

# %%
car['car_company'][100:150]
# Out:
# 100      nissan
# 101      nissan
# 102      nissan
# 103      nissan
# 104      nissan
# 105      nissan
# 106      nissan
# 107     peugeot
# 108     peugeot
# 109     peugeot
# 110     peugeot
# 111     peugeot
# 112     peugeot
# 113     peugeot
# 114     peugeot
# 115     peugeot
# 116     peugeot
# 117     peugeot
# 118    plymouth
# 119    plymouth
# 120    plymouth
# 121    plymouth
# 122    plymouth
# 123    plymouth
# 124    plymouth
# 125     porsche
# 126     porsche
# 127     porsche
# 128     porsche
# 129     porsche
# 130     renault
# 131     renault
# 132        saab
# 133        saab
# 134        saab
# 135        saab
# 136        saab
# 137        saab
# 138      subaru
# 139      subaru
# 140      subaru
# 141      subaru
# 142      subaru
# 143      subaru
# 144      subaru
# 145      subaru
# 146      subaru
# 147      subaru
# 148      subaru
# 149      subaru
# Name: car_company, dtype: object

# %%
car.loc[(car['car_company']=='Nissan') , 'car_company']='nissan'

# %%
car['car_company'][50:100]
# Out:
# 50         mazda
# 51         mazda
# 52         mazda
# 53         mazda
# 54         mazda
# 55         mazda
# 56         mazda
# 57         mazda
# 58         mazda
# 59         mazda
# 60         mazda
# 61         mazda
# 62         mazda
# 63         mazda
# 64         mazda
# 65         mazda
# 66         mazda
# 67         buick
# 68         buick
# 69         buick
# 70         buick
# 71         buick
# 72         buick
# 73         buick
# 74         buick
# 75       mercury
# 76    mitsubishi
# 77    mitsubishi
# 78    mitsubishi
# 79    mitsubishi
# 80    mitsubishi
# 81    mitsubishi
# 82    mitsubishi
# 83    mitsubishi
# 84    mitsubishi
# 85    mitsubishi
# 86    mitsubishi
# 87    mitsubishi
# 88    mitsubishi
# 89        nissan
# 90        nissan
# 91        nissan
# 92        nissan
# 93        nissan
# 94        nissan
# 95        nissan
# 96        nissan
# 97        nissan
# 98        nissan
# 99        nissan
# Name: car_company, dtype: object

# %%
car['car_company'].value_counts()
# Out:
# toyota         32
# nissan         18
# mazda          17
# honda          13
# mitsubishi     13
# volkswagen     12
# subaru         12
# volvo          11
# peugeot        11
# dodge           9
# buick           8
# bmw             8
# audi            7
# plymouth        7
# saab            6
# porsche         5
# isuzu           4
# jaguar          3
# chevrolet       3
# alfa-romero     3
# renault         2
# mercury         1
# Name: car_company, dtype: int64

# %%
car=car.drop('CarName',axis=1)

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   fueltype          205 non-null    object
#  3   aspiration        205 non-null    object
#  4   doornumber        205 non-null    object
#  5   carbody           205 non-null    object
#  6   drivewheel        205 non-null    object
#  7   enginelocation    205 non-null    object
#  8   wheelbase         205 non-null    float64
#  9   carlength         205 non-null    float64
#  10  carwidth          205 non-null    float64
#  11  carheight         205 non-null    float64
#  12  curbweight        205 non-null    int64
#  13  enginetype        205 non-null    object
#  14  cylindernumber    205 non-null    object
#  15  enginesize        205 non-null    int64
# ...

# %%
car.head()
# Out:
#    car_ID  symboling fueltype aspiration doornumber      carbody drivewheel  \
# 0       1          3      gas        std        two  convertible        rwd
# 1       2          3      gas        std        two  convertible        rwd
# 2       3          1      gas        std        two    hatchback        rwd
# 3       4          2      gas        std       four        sedan        fwd
# 4       5          2      gas        std       four        sedan        4wd
#
#   enginelocation  wheelbase  carlength  ...  fuelsystem  boreratio  stroke  \
# 0          front       88.6      168.8  ...        mpfi       3.47    2.68
# 1          front       88.6      168.8  ...        mpfi       3.47    2.68
# 2          front       94.5      171.2  ...        mpfi       2.68    3.47
# 3          front       99.8      176.6  ...        mpfi       3.19    3.40
# 4          front       99.4      176.6  ...        mpfi       3.19    3.40
#
# ...

# %%
car.columns
# Out:
# Index(['car_ID', 'symboling', 'fueltype', 'aspiration', 'doornumber',
#        'carbody', 'drivewheel', 'enginelocation', 'wheelbase', 'carlength',
#        'carwidth', 'carheight', 'curbweight', 'enginetype', 'cylindernumber',
#        'enginesize', 'fuelsystem', 'boreratio', 'stroke', 'compressionratio',
#        'horsepower', 'peakrpm', 'citympg', 'highwaympg', 'price',
#        'car_company'],
#       dtype='object')

# %%
car['cylindernumber'].value_counts()
# Out:
# four      159
# six        24
# five       11
# eight       5
# two         4
# three       1
# twelve      1
# Name: cylindernumber, dtype: int64

# %%
#converting string to number
def num_map(x):
    return x.map({'two':2,'three':3,'four':4,'five':5,'six':6,'eight':8,'twelve':12})

# %%
car['doornumber'].value_counts()
# Out:
# four    115
# two      90
# Name: doornumber, dtype: int64

# %%
car[['doornumber','cylindernumber']]=car[['doornumber','cylindernumber']].apply(num_map)

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   fueltype          205 non-null    object
#  3   aspiration        205 non-null    object
#  4   doornumber        205 non-null    int64
#  5   carbody           205 non-null    object
#  6   drivewheel        205 non-null    object
#  7   enginelocation    205 non-null    object
#  8   wheelbase         205 non-null    float64
#  9   carlength         205 non-null    float64
#  10  carwidth          205 non-null    float64
#  11  carheight         205 non-null    float64
#  12  curbweight        205 non-null    int64
#  13  enginetype        205 non-null    object
#  14  cylindernumber    205 non-null    int64
#  15  enginesize        205 non-null    int64
# ...

# %%
car_categorical=car.select_dtypes('object')

# %%
car_categorical
# Out:
#     fueltype aspiration      carbody drivewheel enginelocation enginetype  \
# 0        gas        std  convertible        rwd          front       dohc
# 1        gas        std  convertible        rwd          front       dohc
# 2        gas        std    hatchback        rwd          front       ohcv
# 3        gas        std        sedan        fwd          front        ohc
# 4        gas        std        sedan        4wd          front        ohc
# ..       ...        ...          ...        ...            ...        ...
# 200      gas        std        sedan        rwd          front        ohc
# 201      gas      turbo        sedan        rwd          front        ohc
# 202      gas        std        sedan        rwd          front       ohcv
# 203   diesel      turbo        sedan        rwd          front        ohc
# 204      gas      turbo        sedan        rwd          front        ohc
#
#     fuelsystem  car_company
# 0         mpfi  alfa-romero
# ...

# %%
car_dummies=pd.get_dummies(car_categorical,drop_first=True)

# %%
car_dummies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 43 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   fueltype_gas            205 non-null    uint8
#  1   aspiration_turbo        205 non-null    uint8
#  2   carbody_hardtop         205 non-null    uint8
#  3   carbody_hatchback       205 non-null    uint8
#  4   carbody_sedan           205 non-null    uint8
#  5   carbody_wagon           205 non-null    uint8
#  6   drivewheel_fwd          205 non-null    uint8
#  7   drivewheel_rwd          205 non-null    uint8
#  8   enginelocation_rear     205 non-null    uint8
#  9   enginetype_dohcv        205 non-null    uint8
#  10  enginetype_l            205 non-null    uint8
#  11  enginetype_ohc          205 non-null    uint8
#  12  enginetype_ohcf         205 non-null    uint8
#  13  enginetype_ohcv         205 non-null    uint8
# ...

# %%
car=car.drop(list(car_categorical.columns),axis=1)

# %%
car.shape
# Out:
# (205, 18)

# %%
car_dummies.shape
# Out:
# (205, 43)

# %%
car=pd.concat([car,car_dummies],axis=1)

# %%
car.shape
# Out:
# (205, 61)

# %%
car.head()
# Out:
#    car_ID  symboling  doornumber  wheelbase  carlength  carwidth  carheight  \
# 0       1          3           2       88.6      168.8      64.1       48.8
# 1       2          3           2       88.6      168.8      64.1       48.8
# 2       3          1           2       94.5      171.2      65.5       52.4
# 3       4          2           4       99.8      176.6      66.2       54.3
# 4       5          2           4       99.4      176.6      66.4       54.3
#
#    curbweight  cylindernumber  enginesize  ...  car_company_nissan  \
# 0        2548               4         130  ...                   0
# 1        2548               4         130  ...                   0
# 2        2823               6         152  ...                   0
# 3        2337               4         109  ...                   0
# 4        2824               5         136  ...                   0
#
#    car_company_peugeot  car_company_plymouth  car_company_porsche  \
# ...

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 61 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   car_ID                  205 non-null    int64
#  1   symboling               205 non-null    int64
#  2   doornumber              205 non-null    int64
#  3   wheelbase               205 non-null    float64
#  4   carlength               205 non-null    float64
#  5   carwidth                205 non-null    float64
#  6   carheight               205 non-null    float64
#  7   curbweight              205 non-null    int64
#  8   cylindernumber          205 non-null    int64
#  9   enginesize              205 non-null    int64
#  10  boreratio               205 non-null    float64
#  11  stroke                  205 non-null    float64
#  12  compressionratio        205 non-null    float64
#  13  horsepower              205 non-null    int64
# ...

# %%
car.drop('car_ID',axis=1,inplace=True)

# %%
car.head()
# Out:
#    symboling  doornumber  wheelbase  carlength  carwidth  carheight  \
# 0          3           2       88.6      168.8      64.1       48.8
# 1          3           2       88.6      168.8      64.1       48.8
# 2          1           2       94.5      171.2      65.5       52.4
# 3          2           4       99.8      176.6      66.2       54.3
# 4          2           4       99.4      176.6      66.4       54.3
#
#    curbweight  cylindernumber  enginesize  boreratio  ...  car_company_nissan  \
# 0        2548               4         130       3.47  ...                   0
# 1        2548               4         130       3.47  ...                   0
# 2        2823               6         152       2.68  ...                   0
# 3        2337               4         109       3.19  ...                   0
# 4        2824               5         136       3.19  ...                   0
#
#    car_company_peugeot  car_company_plymouth  car_company_porsche  \
# ...

# %% [markdown]
# # Model Building

# %%
from sklearn.model_selection import train_test_split

# %%
df_train,df_test=train_test_split(car,train_size=0.7,test_size=0.3,random_state=100)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 60 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   symboling               205 non-null    int64
#  1   doornumber              205 non-null    int64
#  2   wheelbase               205 non-null    float64
#  3   carlength               205 non-null    float64
#  4   carwidth                205 non-null    float64
#  5   carheight               205 non-null    float64
#  6   curbweight              205 non-null    int64
#  7   cylindernumber          205 non-null    int64
#  8   enginesize              205 non-null    int64
#  9   boreratio               205 non-null    float64
#  10  stroke                  205 non-null    float64
#  11  compressionratio        205 non-null    float64
#  12  horsepower              205 non-null    int64
#  13  peakrpm                 205 non-null    int64
# ...

# %%
car.columns
# Out:
# Index(['symboling', 'doornumber', 'wheelbase', 'carlength', 'carwidth',
#        'carheight', 'curbweight', 'cylindernumber', 'enginesize', 'boreratio',
#        'stroke', 'compressionratio', 'horsepower', 'peakrpm', 'citympg',
#        'highwaympg', 'price', 'fueltype_gas', 'aspiration_turbo',
#        'carbody_hardtop', 'carbody_hatchback', 'carbody_sedan',
#        'carbody_wagon', 'drivewheel_fwd', 'drivewheel_rwd',
#        'enginelocation_rear', 'enginetype_dohcv', 'enginetype_l',
#        'enginetype_ohc', 'enginetype_ohcf', 'enginetype_ohcv',
#        'enginetype_rotor', 'fuelsystem_2bbl', 'fuelsystem_4bbl',
#        'fuelsystem_idi', 'fuelsystem_mfi', 'fuelsystem_mpfi',
#        'fuelsystem_spdi', 'fuelsystem_spfi', 'car_company_audi',
#        'car_company_bmw', 'car_company_buick', 'car_company_chevrolet',
#        'car_company_dodge', 'car_company_honda', 'car_company_isuzu',
#        'car_company_jaguar', 'car_company_mazda', 'car_company_mercury',
# ...

# %%
varlist=['symboling', 'doornumber', 'wheelbase', 'carlength', 'carwidth',
       'carheight', 'curbweight', 'cylindernumber', 'enginesize', 'boreratio',
       'stroke', 'compressionratio', 'horsepower', 'peakrpm', 'citympg',
       'highwaympg']

# %%
df_train[varlist]=scaler.fit_transform(df_train[varlist])

# %%
df_train.head()
# Out:
#      symboling  doornumber  wheelbase  carlength  carwidth  carheight  \
# 122   0.170159    0.887412  -0.811836  -0.487238 -0.924500  -1.134628
# 125   1.848278   -1.126872  -0.677177  -0.359789  1.114978  -1.382026
# 166   0.170159   -1.126872  -0.677177  -0.375720 -0.833856  -0.392434
# 1     1.848278   -1.126872  -1.670284  -0.367754 -0.788535  -1.959288
# 199  -1.507960    0.887412   0.972390   1.225364  0.616439   1.627983
#
#      curbweight  cylindernumber  enginesize  boreratio  ...  \
# 122   -0.642128       -0.351431   -0.660242  -1.297329  ...
# 125    0.439415       -0.351431    0.637806   2.432256  ...
# 166   -0.441296       -0.351431   -0.660242  -0.259197  ...
# 1      0.015642       -0.351431    0.123485   0.625138  ...
# 199    1.137720       -0.351431    0.123485   1.201877  ...
#
#      car_company_nissan  car_company_peugeot  car_company_plymouth  \
# 122                   0                    0                     1
# ...

# %%
X_train=df_train

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lr.coef_
# Out:
# array([-6.88567127e+01,  1.59791915e+02,  1.67620993e+03, -9.40501426e+02,
#         1.66728468e+03, -1.32048230e+03,  2.11588268e+03, -2.24692316e+03,
#         7.76550622e+03, -2.46121683e+03, -8.48196473e+02, -3.46772929e+03,
#        -9.97487191e+02,  1.47072292e+03,  4.74859336e+02,  6.18660770e+02,
#        -5.55423212e+03,  3.05402080e+03, -4.42195370e+03, -4.93031210e+03,
#        -4.14820586e+03, -3.45584500e+03, -4.90769833e+02,  3.55723578e+02,
#         7.66348624e+03,  7.02233939e+03,  7.73848811e+03,  2.20125928e+03,
#         4.74919992e+03,  6.31832027e+01,  8.71702434e+03,  9.33222641e+02,
#        -2.37609763e+03,  5.55423212e+03, -7.27595761e-12, -3.11421930e+02,
#        -4.55560035e+02, -2.72848411e-12, -9.98396594e+02,  7.91156079e+03,
#         8.74512513e+02, -4.59870841e+03, -5.59057700e+03, -3.90189453e+03,
#        -2.38532312e+03, -1.93079078e+03, -1.22727036e+03,  4.54747351e-12,
# ...

# %%
lr.intercept_
# Out:
# 20603.96150996345

# %%
from sklearn.feature_selection import RFE

# %%
lr=LinearRegression()
rfe1=RFE(lr,15)
rfe1.fit(X_train,y_train)
# Out:
# RFE(estimator=LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#                                normalize=False),
#     n_features_to_select=15, step=1, verbose=0)

# %%
rfe1.ranking_
# Out:
# array([41, 38, 27, 30,  1, 25, 17, 31,  1, 18, 32,  1, 22, 23, 35, 29,  1,
#        16, 14, 12, 13, 15, 34, 37,  1, 21,  1, 19,  1, 42,  1, 26, 10,  1,
#        43, 40, 36, 45,  9,  1, 33,  8,  6,  4, 24, 28,  1, 44,  1,  2,  1,
#         7, 11,  1, 20,  1,  3,  5, 39])

# %%
rfe1.support_
# Out:
# array([False, False, False, False,  True, False, False, False,  True,
#        False, False,  True, False, False, False, False,  True, False,
#        False, False, False, False, False, False,  True, False,  True,
#        False,  True, False,  True, False, False,  True, False, False,
#        False, False, False,  True, False, False, False, False, False,
#        False,  True, False,  True, False,  True, False, False,  True,
#        False,  True, False, False, False])

# %%
import statsmodels.api as sm

# %%
col1=X_train.columns[rfe1.support_]

# %%
X_train_rfe1=X_train[col1]

# %%
X_train_rfe1.head()
# Out:
#      carwidth  enginesize  compressionratio  fueltype_gas  \
# 122 -0.924500   -0.660242         -0.172569             1
# 125  1.114978    0.637806         -0.146125             1
# 166 -0.833856   -0.660242         -0.172569             1
# 1   -0.788535    0.123485         -0.278345             1
# 199  0.616439    0.123485         -0.675002             1
#
#      enginelocation_rear  enginetype_l  enginetype_ohcf  enginetype_rotor  \
# 122                    0             0                0                 0
# 125                    0             0                0                 0
# 166                    0             0                0                 0
# 1                      0             0                0                 0
# 199                    0             0                0                 0
#
#      fuelsystem_idi  car_company_bmw  car_company_mazda  \
# 122               0                0                  0
# ...

# %%
X_train_rfe1=sm.add_constant(X_train_rfe1)

# %%
lr1=sm.OLS(y_train,X_train_rfe1).fit()
lr1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.920
# Model:                            OLS   Adj. R-squared:                  0.912
# Method:                 Least Squares   F-statistic:                     114.1
# Date:                Sat, 06 Nov 2021   Prob (F-statistic):           4.59e-64
# Time:                        15:46:27   Log-Likelihood:                -1303.5
# No. Observations:                 143   AIC:                             2635.
# Df Residuals:                     129   BIC:                             2676.
# Df Model:                          13
# Covariance Type:            nonrobust
# ...
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# ...

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
vif=pd.DataFrame()

# %%
vif['Features']=X_train_rfe1.columns

# %%
vif['VIF']=[variance_inflation_factor(X_train_rfe1.values,i) for i in range(X_train_rfe1.shape[1])]

vif
# Out:
#                   Features        VIF
# 0                    const   0.000000
# 1                 carwidth   3.377903
# 2               enginesize   3.296894
# 3         compressionratio  42.320787
# 4             fueltype_gas        inf
# 5      enginelocation_rear        inf
# 6             enginetype_l   8.992471
# 7          enginetype_ohcf        inf
# 8         enginetype_rotor   1.547646
# 9           fuelsystem_idi        inf
# 10         car_company_bmw   1.115332
# 11       car_company_mazda   1.499523
# 12  car_company_mitsubishi   1.203474
# 13     car_company_peugeot   9.732083
# 14     car_company_renault   1.014613
# 15      car_company_subaru        inf

# %%
vif['VIF']=round(vif['VIF'],2)

# %%
vif.sort_values(by='VIF',ascending=False)
# Out:
#                   Features    VIF
# 4             fueltype_gas    inf
# 5      enginelocation_rear    inf
# 7          enginetype_ohcf    inf
# 9           fuelsystem_idi    inf
# 15      car_company_subaru    inf
# 3         compressionratio  42.32
# 13     car_company_peugeot   9.73
# 6             enginetype_l   8.99
# 1                 carwidth   3.38
# 2               enginesize   3.30
# 8         enginetype_rotor   1.55
# 11       car_company_mazda   1.50
# 12  car_company_mitsubishi   1.20
# 10         car_company_bmw   1.12
# 14     car_company_renault   1.01
# 0                    const   0.00

# %%
lm=LinearRegression()
rfe2=RFE(lm,10)
rfe2.fit(X_train,y_train)
# Out:
# RFE(estimator=LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#                                normalize=False),
#     n_features_to_select=10, step=1, verbose=0)

# %%
col2=X_train.columns[rfe2.support_]
X_train_rfe2=X_train[col2]
X_train_rfe2=sm.add_constant(X_train_rfe2)
lm2=sm.OLS(y_train,X_train_rfe2).fit()
print(lm2.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.907
# Model:                            OLS   Adj. R-squared:                  0.901
# Method:                 Least Squares   F-statistic:                     144.3
# Date:                Sat, 06 Nov 2021   Prob (F-statistic):           3.98e-64
# Time:                        15:48:31   Log-Likelihood:                -1314.2
# No. Observations:                 143   AIC:                             2648.
# Df Residuals:                     133   BIC:                             2678.
# Df Model:                           9
# Covariance Type:            nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                1.266e+04    235.167     53.845      0.000    1.22e+04    1.31e+04
# ...

# %%
vif=pd.DataFrame()
vif['Features']=X_train_rfe2.columns
vif['VIF']=[variance_inflation_factor(X_train_rfe2.values,i) for i in range(X_train_rfe2.shape[1])]
vif.sort_values(by='VIF',ascending=False)
# Out:
#                Features       VIF
# 3   enginelocation_rear       inf
# 5       enginetype_ohcf       inf
# 10   car_company_subaru       inf
# 8   car_company_peugeot  9.494513
# 4          enginetype_l  8.952555
# 2            enginesize  3.226114
# 1              carwidth  3.167483
# 0                 const  1.307825
# 6      enginetype_rotor  1.150062
# 7       car_company_bmw  1.092396
# 9   car_company_renault  1.006775

# %%
X_train_rfe2.drop('car_company_subaru',axis=1,inplace=True)

# %%
X_train_rfe2=sm.add_constant(X_train_rfe2)
lm2=sm.OLS(y_train,X_train_rfe2).fit()
print(lm2.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.907
# Model:                            OLS   Adj. R-squared:                  0.901
# Method:                 Least Squares   F-statistic:                     144.3
# Date:                Sat, 06 Nov 2021   Prob (F-statistic):           3.98e-64
# Time:                        15:48:59   Log-Likelihood:                -1314.2
# No. Observations:                 143   AIC:                             2648.
# Df Residuals:                     133   BIC:                             2678.
# Df Model:                           9
# Covariance Type:            nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                1.266e+04    235.167     53.845      0.000    1.22e+04    1.31e+04
# ...

# %%
vif=pd.DataFrame()
vif['Features']=X_train_rfe2.columns
vif['VIF']=[variance_inflation_factor(X_train_rfe2.values,i) for i in range(X_train_rfe2.shape[1])]
vif.sort_values(by='VIF',ascending=False)
# Out:
#               Features       VIF
# 8  car_company_peugeot  9.494513
# 4         enginetype_l  8.952555
# 2           enginesize  3.226114
# 1             carwidth  3.167483
# 0                const  1.307825
# 3  enginelocation_rear  1.186865
# 6     enginetype_rotor  1.150062
# 5      enginetype_ohcf  1.117740
# 7      car_company_bmw  1.092396
# 9  car_company_renault  1.006775

# %%
X_train_rfe2.drop('enginetype_ohcf',axis=1,inplace=True)

# %%
X_train_rfe2=sm.add_constant(X_train_rfe2)
lm2=sm.OLS(y_train,X_train_rfe2).fit()
print(lm2.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.906
# Model:                            OLS   Adj. R-squared:                  0.900
# Method:                 Least Squares   F-statistic:                     160.8
# Date:                Sat, 06 Nov 2021   Prob (F-statistic):           8.22e-65
# Time:                        15:49:25   Log-Likelihood:                -1315.3
# No. Observations:                 143   AIC:                             2649.
# Df Residuals:                     134   BIC:                             2675.
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                1.256e+04    225.167     55.790      0.000    1.21e+04     1.3e+04
# ...

# %%
vif=pd.DataFrame()
vif['Features']=X_train_rfe2.columns
vif['VIF']=[variance_inflation_factor(X_train_rfe2.values,i) for i in range(X_train_rfe2.shape[1])]
vif.sort_values(by='VIF',ascending=False)
# Out:
#               Features       VIF
# 7  car_company_peugeot  9.492904
# 4         enginetype_l  8.937210
# 2           enginesize  3.197559
# 1             carwidth  3.165959
# 0                const  1.189897
# 5     enginetype_rotor  1.141595
# 6      car_company_bmw  1.091189
# 3  enginelocation_rear  1.088153
# 8  car_company_renault  1.005302

# %%
X_train_rfe2.drop('car_company_peugeot',axis=1,inplace=True)

# %%
X_train_rfe2=sm.add_constant(X_train_rfe2)
lm2=sm.OLS(y_train,X_train_rfe2).fit()
print(lm2.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.897
# Model:                            OLS   Adj. R-squared:                  0.891
# Method:                 Least Squares   F-statistic:                     167.5
# Date:                Sat, 06 Nov 2021   Prob (F-statistic):           2.49e-63
# Time:                        15:49:51   Log-Likelihood:                -1321.7
# No. Observations:                 143   AIC:                             2659.
# Df Residuals:                     135   BIC:                             2683.
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                1.254e+04    234.591     53.458      0.000    1.21e+04     1.3e+04
# ...

# %%
vif=pd.DataFrame()
vif['Features']=X_train_rfe2.columns
vif['VIF']=[variance_inflation_factor(X_train_rfe2.values,i) for i in range(X_train_rfe2.shape[1])]
vif.sort_values(by='VIF',ascending=False)
# Out:
#               Features       VIF
# 2           enginesize  3.137317
# 1             carwidth  2.906076
# 0                const  1.189050
# 5     enginetype_rotor  1.138946
# 4         enginetype_l  1.093290
# 6      car_company_bmw  1.091108
# 3  enginelocation_rear  1.085818
# 7  car_company_renault  1.004989

# %%
X_train_rfe2.drop('enginetype_l',axis=1,inplace=True)

# %%
X_train_rfe2=sm.add_constant(X_train_rfe2)
lm2=sm.OLS(y_train,X_train_rfe2).fit()
print(lm2.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.896
# Model:                            OLS   Adj. R-squared:                  0.891
# Method:                 Least Squares   F-statistic:                     195.2
# Date:                Sat, 06 Nov 2021   Prob (F-statistic):           2.92e-64
# Time:                        15:50:20   Log-Likelihood:                -1322.3
# No. Observations:                 143   AIC:                             2659.
# Df Residuals:                     136   BIC:                             2679.
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                1.247e+04    225.791     55.247      0.000     1.2e+04    1.29e+04
# ...

# %%
vif=pd.DataFrame()
vif['Features']=X_train_rfe2.columns
vif['VIF']=[variance_inflation_factor(X_train_rfe2.values,i) for i in range(X_train_rfe2.shape[1])]
vif.sort_values(by='VIF',ascending=False)
# Out:
#               Features       VIF
# 2           enginesize  3.009203
# 1             carwidth  2.679605
# 4     enginetype_rotor  1.124589
# 0                const  1.100862
# 5      car_company_bmw  1.090804
# 3  enginelocation_rear  1.084154
# 6  car_company_renault  1.002908

# %% [markdown]
# # Making Prediction

# %%
df_test[varlist]=scaler.transform(df_test[varlist])

# %%
y_test=df_test.pop('price')

# %%
X_test=df_test

# %%
col2
# Out:
# Index(['carwidth', 'enginesize', 'enginelocation_rear', 'enginetype_l',
#        'enginetype_ohcf', 'enginetype_rotor', 'car_company_bmw',
#        'car_company_peugeot', 'car_company_renault', 'car_company_subaru'],
#       dtype='object')

# %%
X_test_rfe2=X_test[col2]

# %%
X_test_rfe2=X_test_rfe2.drop(['car_company_subaru','car_company_peugeot','enginetype_ohcf','enginetype_l'],axis=1)

# %%
X_test_rfe2=sm.add_constant(X_test_rfe2)

# %%
y_pred=lm2.predict(X_test_rfe2)

# %%
plt.scatter(y_test,y_pred)
plt.show()

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,y_pred)
# Out:
# 0.8997211435182687

# %%
col2=col2.drop(['car_company_subaru','car_company_peugeot','enginetype_ohcf','enginetype_l'])

# %%
sns.heatmap(car[col2].corr(),annot=True)
